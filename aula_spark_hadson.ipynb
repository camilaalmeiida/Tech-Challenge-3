# %% [markdown]
# <a href="https://colab.research.google.com/github/camilaalmeiida/Tech-Challenge-3/blob/main/aula_spark_hadson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalando Bibliotecas PySpark

# %%
# Instalando pacote PySpark
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.3)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %%
# Instalação de funções básicas para Spark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %% [markdown]
# ## Iniciando Ambiente spark e Criando a sessão SparkSession

# %%
spark = (
    SparkSession
    .builder
    .master("local[*]")
    .getOrCreate()
)

# %% [markdown]
# ## Consultando versão do Spark

# %%
print(spark.version)
# Out:
# 4.0.3

# %% [markdown]
# ## Importação de Bases.csv

# %%
df_clientes = spark.read.csv('clientes.csv', sep = ';', inferSchema = True, header = True)
df_vendas = spark.read.csv('vendas.csv', sep = ',', inferSchema = True, header = True)

# %%
df_clientes.show()
df_vendas.show()
# Out:
# +----------+--------------------+--------------------+-----+--------------------+---+---------+-------------+
# |cliente_id|                nome|               email|idade|              cidade| UF|     sexo|data_cadastro|
# +----------+--------------------+--------------------+-----+--------------------+---+---------+-------------+
# |         1|        Miguel Porto|eloah69@nasciment...|   51|Sao Bernardo do C...| SP| Feminino|   24/09/2020|
# |         2|Gustavo Henrique ...|   ubarros@gmail.com|   62|            Londrina| PR| Feminino|   28/05/2024|
# |         3|       Julia Correia|ana-lauramoraes@u...|   65|            Sao Luis| MA| Feminino|   08/01/2020|
# |         4|        Pietra Sales| usilveira@ig.com.br|   45|              Recife| PE|Masculino|   22/05/2021|
# |         5|    Guilherme Barros|davi-luizfarias@b...|   24|              Cuiaba| MT| Feminino|   20/04/2021|
# |         6|Sr. Guilherme Rez...|cavalcantieloah@b...|   57|Sao Bernardo do C...| SP|Masculino|   13/08/2023|
# |         7|Dra. Catarina da ...| pTaboao@costela.com|   24|            Teresina| PI|Masculino|   12/06/2020|
# |         8|Luiz Fernando Car...|joao-guilhermemor...|   55|       Florianopolis| SC| Feminino|   29/04/2021|
# |         9|       Vitor da Cruz|fernandorezende@y...|   51|               Belem| PA| Feminino|   08/06/2024|
# |        10|       Vitor da Cruz|fernandorezende@y...|   51|               Belem| PA|Masculino|   31/12/2022|
# |        11|    Valentina Duarte| fmendes@pereira.net|   52|             Vitoria| ES|Masculino|   20/07/2021|
# |        12|     Rafaela Peixoto|cunhasophie@hotma...|   28|             Jundiai| SP|Masculino|   23/06/2022|
# |        13|       Bianca Aragão|agathamendes@barr...|   35|             Vitoria| ES| Feminino|   12/07/2021|
# |        14|         Sofia Rocha|icardoso@goncalve...|   38|      Belo Horizonte| MG| Feminino|   25/08/2020|
# |        15|         Danilo Dias|    araujolara@da.br|   34|             Aracaju| SE| Feminino|   01/02/2023|
# |        16|     Pietro Oliveira|     raquel90@das.br|   19|      Rio de Janeiro| RJ| Feminino|   18/05/2023|
# |        17|Vitor Gabriel Mendes|ana-julia13@hotma...|   47|             Vitoria| ES| Feminino|   07/07/2021|
# |        18|    Valentina Duarte| fmendes@pereira.net|   52|            Blumenau| SC|Masculino|   07/04/2022|
# |        19| Ana Vitória Peixoto|henriquecaldeira@...|   32|         Santo Andre| SP| Feminino|   12/04/2021|
# |        20|     Gabrielly Cunha|davi-luccadas-nev...|   42|      Rio de Janeiro| RJ|Masculino|   17/01/2024|
# +----------+--------------------+--------------------+-----+--------------------+---+---------+-------------+
# only showing top 20 rows
# +--------+----------+----------+--------------+----------+--------------+
# |venda_id|data_venda|cliente_id|       produto|quantidade|valor_unitario|
# +--------+----------+----------+--------------+----------+--------------+
# |       1|2025-02-16|       837|       Monitor|         4|       2666.58|
# |       2|2025-01-02|       321|    Impressora|         5|        480.71|
# |       3|2025-02-04|       256|Fone de Ouvido|         5|        941.84|
# |       4|2025-01-31|       818|        Tablet|         1|       1195.82|
# |       5|2025-02-04|       278|         Mouse|         4|        4242.7|
# |       6|2025-03-01|        59|        Tablet|         2|       2435.03|
# |       7|2025-02-20|        17|        Tablet|         1|         119.4|
# |       8|2025-01-29|       308|        Tablet|         3|       3068.01|
# |       9|2025-01-16|       658|       Teclado|         4|       1757.96|
# |      10|2025-01-16|       188|       Teclado|         4|       1757.96|
# |      11|2025-01-03|       860|       Teclado|         3|       1748.32|
# |      12|2025-02-27|       963|       Celular|         2|       3324.36|
# |      13|2025-01-27|       879|        Tablet|         4|       4583.67|
# |      14|2025-02-21|       415|      Notebook|         4|       2682.12|
# |      15|2025-01-12|       856|        Tablet|         2|        4960.9|
# |      16|2025-01-02|       321|        Tablet|         3|       4410.61|
# |      17|2025-01-28|       804|      Notebook|         4|       3831.37|
# |      18|2025-01-03|       896|       Teclado|         3|       1748.32|
# |      19|2025-01-17|       435|Fone de Ouvido|         1|       1021.43|
# |      20|2025-01-30|       380|Fone de Ouvido|         2|       2157.36|
# +--------+----------+----------+--------------+----------+--------------+
# only showing top 20 rows

# %% [markdown]
# ## Exemplo de RDD

# %%
dados_clientes = [
    (1,"João Silva", "joao.silva@gmail.com", 34, "São Paulo", "SP"),
    (2,"Maria Souza", "maria.souza@gmail.com", 28, "Curitiba", "PR")
]

# %%
rdd_clientes = spark.sparkContext.parallelize(dados_clientes)

# %%
rdd_clientes.collect()
# Out:
# [(1, 'João Silva', 'joao.silva@gmail.com', 34, 'São Paulo', 'SP'),
#  (2, 'Maria Souza', 'maria.souza@gmail.com', 28, 'Curitiba', 'PR')]
